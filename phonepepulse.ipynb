# %%
import pandas as pd
import json
import os
import mysql.connector

# %%
path='C:/Users/ravin/Downloads/pulse-master/pulse-master/data/aggregated/transaction/country/india/state/'

# %%
Agg_state_list=os.listdir(path)

# %%
clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#                           State  Year  Quater           Transacion_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 3589                west-bengal  2022       4     Peer-to-peer payments
# 3590                west-bengal  2022       4         Merchant payments
# 3591                west-bengal  2022       4  Recharge & bill payments
# 3592                west-bengal  2022       4        Financial Services
# 3593                west-bengal  2022       4                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# ...

# %%
path2='C:/Users/ravin/Downloads/pulse-master/pulse-master/data/aggregated/user/country/india/state/'
Agg_user_list=os.listdir(path2)

# %%
clm2={'State':[], 'Year':[],'Quater':[], 'brand':[], 'count':[],'percentage':[]}
for i in Agg_user_list:
    p_i=path2+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            B=json.load(Data)
            try:
              for w in B['data']['usersByDevice']:

                  brand=w['brand']
                  count=w['count']
                  percentage=w['percentage']
                  clm2['percentage'].append(percentage)
                  clm2['brand'].append(brand)
                  clm2['count'].append(count)
                  clm2['State'].append(i)
                  clm2['Year'].append(j)
                  clm2['Quater'].append(int(k.strip('.json')))
            except:
              pass
     
#Succesfully created a dataframe
Agg_Users=pd.DataFrame(clm2)

# %%
Agg_Users
# Out:
#                           State  Year  Quater    brand    count  percentage
# 0     andaman-&-nicobar-islands  2018       1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018       1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018       1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018       1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018       1  OnePlus      332    0.049258
# ...                         ...   ...     ...      ...      ...         ...
# 6727                west-bengal  2022       1   Lenovo   330017    0.015056
# 6728                west-bengal  2022       1  Infinix   284678    0.012987
# 6729                west-bengal  2022       1     Asus   280347    0.012790
# 6730                west-bengal  2022       1    Apple   277752    0.012671
# 6731                west-bengal  2022       1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
path3='C:/Users/ravin/Downloads/pulse-master/pulse-master/data/map/transaction/hover/country/india/state/'
map_state_list=os.listdir(path3)

# %%
clm={'State':[], 'Year':[],'Quater':[],'district':[], 'count':[], 'amount':[]}
for i in map_state_list:
    p_i=path3+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            C=json.load(Data)
            for x in C['data']['hoverDataList']:
              district=x['name']
              count=x['metric'][0]['count']
              amount=x['metric'][0]['amount']
              clm['district'].append(district)
              clm['count'].append(count)
              clm['amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
map_Trans=pd.DataFrame(clm)

# %%
map_Trans
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 14631                west-bengal  2022       4
# 14632                west-bengal  2022       4
# 14633                west-bengal  2022       4
# 14634                west-bengal  2022       4
# 14635                west-bengal  2022       4
#
#                                 district     count        amount
# 0      north and middle andaman district       442  9.316631e+05
# 1                 south andaman district      5688  1.256025e+07
# 2                      nicobars district       528  1.139849e+06
# 3      north and middle andaman district       825  1.317863e+06
# 4                 south andaman district      9395  2.394824e+07
# ...

# %%
path4='C:/Users/ravin/Downloads/pulse-master/pulse-master/data/map/user/hover/country/india/state/'
map_state_list=os.listdir(path4)

# %%
clm={'State':[], 'Year':[],'Quater':[],'district':[], 'registeredUsers':[]}
for i in map_state_list:
    p_i=path4+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            C=json.load(Data)
            for district,values in C['data']['hoverData'].items():
              district=district
              registerdUsers=values['registeredUsers']
              clm['district'].append(district)
              clm['registeredUsers'].append(registerdUsers)

              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
maps_user=pd.DataFrame(clm)

# %%
maps_user
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 14635                west-bengal  2022       4
# 14636                west-bengal  2022       4
# 14637                west-bengal  2022       4
# 14638                west-bengal  2022       4
# 14639                west-bengal  2022       4
#
#                                 district  registeredUsers
# 0      north and middle andaman district              632
# 1                 south andaman district             5846
# 2                      nicobars district              262
# 3      north and middle andaman district              911
# 4                 south andaman district             8143
# ...

# %%
path5='C:/Users/ravin/Downloads/pulse-master/pulse-master/data/top/transaction/country/india/state/'
top_state_list=os.listdir(path5)

# %%
clm={'State':[], 'Year':[],'Quater':[],'district':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in top_state_list:
    p_i=path5+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            E=json.load(Data)
            for z in E['data']['districts']:
              district=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              clm['district'].append(district)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
top_Trans=pd.DataFrame(clm)

# %%
top_Trans
# Out:
#                           State  Year  Quater                    district  \
# 0     andaman-&-nicobar-islands  2018       1               south andaman
# 1     andaman-&-nicobar-islands  2018       1                    nicobars
# 2     andaman-&-nicobar-islands  2018       1    north and middle andaman
# 3     andaman-&-nicobar-islands  2018       2               south andaman
# 4     andaman-&-nicobar-islands  2018       2                    nicobars
# ...                         ...   ...     ...                         ...
# 5915                west-bengal  2022       4  south twenty four parganas
# 5916                west-bengal  2022       4             purba medinipur
# 5917                west-bengal  2022       4                     hooghly
# 5918                west-bengal  2022       4                      howrah
# 5919                west-bengal  2022       4           paschim medinipur
#
#       Transacion_count  Transacion_amount
# ...

# %%
path6='C:/Users/ravin/Downloads/pulse-master/pulse-master/data/top/user/country/india/state/'
top_state_list=os.listdir(path6)

# %%
clm={'State':[], 'Year':[],'Quater':[],'district':[], 'registeredUsers':[]}
for i in top_state_list:
    p_i=path6+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            F=json.load(Data)
            for z in F['data']['districts']:
              district=z['name']
              registeredUsers=z["registeredUsers"]

              clm['district'].append(district)
              clm['registeredUsers'].append(registeredUsers)

              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
top_users=pd.DataFrame(clm)

# %%
top_users
# Out:
#                           State  Year  Quater                  district  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018       1                  nicobars
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2  north and middle andaman
# ...                         ...   ...     ...                       ...
# 5915                west-bengal  2022       4                    howrah
# 5916                west-bengal  2022       4                     nadia
# 5917                west-bengal  2022       4           purba medinipur
# 5918                west-bengal  2022       4         paschim medinipur
# 5919                west-bengal  2022       4           purba bardhaman
#
#       registeredUsers
# 0                5846
# 1                 632
# 2                 262
# ...

# %%
Agg_Trans.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3589    False
# 3590    False
# 3591    False
# 3592    False
# 3593    False
# Length: 3594, dtype: bool

# %%
Agg_Trans.isnull()
# Out:
#       State   Year  Quater  Transacion_type  Transacion_count  \
# 0     False  False   False            False             False
# 1     False  False   False            False             False
# 2     False  False   False            False             False
# 3     False  False   False            False             False
# 4     False  False   False            False             False
# ...     ...    ...     ...              ...               ...
# 3589  False  False   False            False             False
# 3590  False  False   False            False             False
# 3591  False  False   False            False             False
# 3592  False  False   False            False             False
# 3593  False  False   False            False             False
#
#       Transacion_amount
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 3589              False
# ...

# %%
Agg_Users.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6727    False
# 6728    False
# 6729    False
# 6730    False
# 6731    False
# Length: 6732, dtype: bool

# %%
Agg_Users.isnull()
# Out:
#       State   Year  Quater  brand  count  percentage
# 0     False  False   False  False  False       False
# 1     False  False   False  False  False       False
# 2     False  False   False  False  False       False
# 3     False  False   False  False  False       False
# 4     False  False   False  False  False       False
# ...     ...    ...     ...    ...    ...         ...
# 6727  False  False   False  False  False       False
# 6728  False  False   False  False  False       False
# 6729  False  False   False  False  False       False
# 6730  False  False   False  False  False       False
# 6731  False  False   False  False  False       False
#
# [6732 rows x 6 columns]

# %%
map_Trans.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14631    False
# 14632    False
# 14633    False
# 14634    False
# 14635    False
# Length: 14636, dtype: bool

# %%
map_Trans.isnull()
# Out:
#        State   Year  Quater  district  count  amount
# 0      False  False   False     False  False   False
# 1      False  False   False     False  False   False
# 2      False  False   False     False  False   False
# 3      False  False   False     False  False   False
# 4      False  False   False     False  False   False
# ...      ...    ...     ...       ...    ...     ...
# 14631  False  False   False     False  False   False
# 14632  False  False   False     False  False   False
# 14633  False  False   False     False  False   False
# 14634  False  False   False     False  False   False
# 14635  False  False   False     False  False   False
#
# [14636 rows x 6 columns]

# %%
maps_user.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14635    False
# 14636    False
# 14637    False
# 14638    False
# 14639    False
# Length: 14640, dtype: bool

# %%
maps_user.isnull()
# Out:
#        State   Year  Quater  district  registeredUsers
# 0      False  False   False     False            False
# 1      False  False   False     False            False
# 2      False  False   False     False            False
# 3      False  False   False     False            False
# 4      False  False   False     False            False
# ...      ...    ...     ...       ...              ...
# 14635  False  False   False     False            False
# 14636  False  False   False     False            False
# 14637  False  False   False     False            False
# 14638  False  False   False     False            False
# 14639  False  False   False     False            False
#
# [14640 rows x 5 columns]

# %%
top_Trans.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5915    False
# 5916    False
# 5917    False
# 5918    False
# 5919    False
# Length: 5920, dtype: bool

# %%
top_users.isnull()
# Out:
#       State   Year  Quater  district  registeredUsers
# 0     False  False   False     False            False
# 1     False  False   False     False            False
# 2     False  False   False     False            False
# 3     False  False   False     False            False
# 4     False  False   False     False            False
# ...     ...    ...     ...       ...              ...
# 5915  False  False   False     False            False
# 5916  False  False   False     False            False
# 5917  False  False   False     False            False
# 5918  False  False   False     False            False
# 5919  False  False   False     False            False
#
# [5920 rows x 5 columns]

# %%
Agg_Trans.to_csv('Agg_Trans.csv',index='False')
Agg_Users.to_csv('Agg_Users.csv',index='False')
map_Trans.to_csv('map_Trans.csv',index='False')
maps_user.to_csv('map_user.csv',index='False')
top_Trans.to_csv('top_Trans.csv',index='False')
top_users.to_csv('top_user.csv',index='False')

# %%
Agg_Trans=pd.read_csv('C:/Users/ravin/Downloads/Agg_Trans.csv')
Agg_Users=pd.read_csv('C:/Users/ravin/Downloads/Agg_Users.csv')
map_Trans=pd.read_csv('C:/Users/ravin/Downloads/map_Trans.csv')
map_users=pd.read_csv('C:/Users/ravin/Downloads/map_user.csv')
top_Trans=pd.read_csv('C:/Users/ravin/Downloads/top_Trans.csv')
top_users=pd.read_csv('C:/Users/ravin/Downloads/top_user.csv')

# %%
Agg_Trans
# Out:
#       Unnamed: 0                      State  Year  Quater  \
# 0              0  andaman-&-nicobar-islands  2018       1
# 1              1  andaman-&-nicobar-islands  2018       1
# 2              2  andaman-&-nicobar-islands  2018       1
# 3              3  andaman-&-nicobar-islands  2018       1
# 4              4  andaman-&-nicobar-islands  2018       1
# ...          ...                        ...   ...     ...
# 3589        3589                west-bengal  2022       4
# 3590        3590                west-bengal  2022       4
# 3591        3591                west-bengal  2022       4
# 3592        3592                west-bengal  2022       4
# 3593        3593                west-bengal  2022       4
#
#                Transacion_type  Transacion_count  Transacion_amount
# 0     Recharge & bill payments              4200       1.845307e+06
# 1        Peer-to-peer payments              1871       1.213866e+07
# ...

# %%
top_users
# Out:
#       Unnamed: 0                      State  Year  Quater  \
# 0              0  andaman-&-nicobar-islands  2018       1
# 1              1  andaman-&-nicobar-islands  2018       1
# 2              2  andaman-&-nicobar-islands  2018       1
# 3              3  andaman-&-nicobar-islands  2018       2
# 4              4  andaman-&-nicobar-islands  2018       2
# ...          ...                        ...   ...     ...
# 5915        5915                west-bengal  2022       4
# 5916        5916                west-bengal  2022       4
# 5917        5917                west-bengal  2022       4
# 5918        5918                west-bengal  2022       4
# 5919        5919                west-bengal  2022       4
#
#                       district  registeredUsers
# 0                south andaman             5846
# 1     north and middle andaman              632
# 2                     nicobars              262
# 3                south andaman             8143
# ...

# %%
import mysql.connector

# %%
top_users
# Out:
#       Unnamed: 0                      State  Year  Quater  \
# 0              0  andaman-&-nicobar-islands  2018       1
# 1              1  andaman-&-nicobar-islands  2018       1
# 2              2  andaman-&-nicobar-islands  2018       1
# 3              3  andaman-&-nicobar-islands  2018       2
# 4              4  andaman-&-nicobar-islands  2018       2
# ...          ...                        ...   ...     ...
# 5915        5915                west-bengal  2022       4
# 5916        5916                west-bengal  2022       4
# 5917        5917                west-bengal  2022       4
# 5918        5918                west-bengal  2022       4
# 5919        5919                west-bengal  2022       4
#
#                       district  registeredUsers
# 0                south andaman             5846
# 1     north and middle andaman              632
# 2                     nicobars              262
# 3                south andaman             8143
# ...

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="phonepepulse"
  
)

print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
csv_file = 'Agg_Trans.csv'
df = pd.read_csv(csv_file)

# %%
table_name = 'Agg_Trans'

for index, row in df.iterrows():
 sql = f"INSERT INTO Agg_Trans (State, Year, Quarter, Transaction_Type,  Transaction_count, Transaction_amount) VALUES (%s, %s, %s, %s, %s, %s);"
 values = (row['State'], row['Year'], row['Quater'], row['Transacion_type'], row['Transacion_count'], row['Transacion_amount'])
 mycursor.execute(sql, values)


mydb.commit()
mycursor.close()
mydb.close()

# %%
csv_file = 'Agg_Users.csv'
df = pd.read_csv(csv_file)

# %%
for index, row in df.iterrows():
 sql = f"INSERT INTO Agg_Users (State, Year, Quarter, brand,  count, percentage) VALUES (%s, %s, %s, %s, %s, %s);"
 values = (row['State'], row['Year'], row['Quater'], row['brand'], row['count'], row['percentage'])
 mycursor.execute(sql, values)


mydb.commit()
mycursor.close()
mydb.close()

# %%
csv_file = 'map_Trans.csv'
df = pd.read_csv(csv_file)

# %%
for index, row in df.iterrows():
 sql = f"INSERT INTO map_trans (State, Year, Quarter, 	district,  count, amount) VALUES (%s, %s, %s, %s, %s, %s);"
 values = (row['State'], row['Year'], row['Quater'], row['district'], row['count'], row['amount'])
 mycursor.execute(sql, values)


mydb.commit()
mycursor.close()
mydb.close()

# %%
csv_file = 'map_user.csv'
df = pd.read_csv(csv_file)

# %%
for index, row in df.iterrows():
 sql = f"INSERT INTO map_users (State, Year, Quarter, 	district, registeredUsers) VALUES (%s, %s, %s, %s, %s);"
 values = (row['State'], row['Year'], row['Quater'], row['district'], row['registeredUsers'])
 mycursor.execute(sql, values)


mydb.commit()
mycursor.close()
mydb.close()

# %%
csv_file = 'top_Trans.csv'
df = pd.read_csv(csv_file)

# %%
for index, row in df.iterrows():
 sql = f"INSERT INTO top_trans (State, Year, Quarter, 	district, Transaction_count,Transaction_amount) VALUES (%s, %s, %s, %s, %s,%s);"
 values = (row['State'], row['Year'], row['Quater'], row['district'], row['Transacion_count'],row['Transacion_amount'])
 mycursor.execute(sql, values)
mydb.commit()
mycursor.close()
mydb.close()

# %%
csv_file = 'top_user.csv'
df = pd.read_csv(csv_file)

# %%
for index, row in df.iterrows():
 sql = f"INSERT INTO top_users (State, Year, Quarter,district,registeredUsers) VALUES (%s, %s, %s, %s, %s);"
 values = (row['State'], row['Year'], row['Quater'], row['district'], row['registeredUsers'])
 mycursor.execute(sql, values)
mydb.commit()
mycursor.close()
mydb.close()
